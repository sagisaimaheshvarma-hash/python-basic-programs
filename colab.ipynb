# %%
s="Gitam University"
s1=input()
print(s)
print(s1)
print(id(s))
# Out:
# Gitam University
# cse cs
# 133114398767216

# %%
s="g"+s[1:]
print(s)
print(id(s))
# Out:
# gitam University
# 133114397022896

# %%
s1="cse"
s2=s+" "+s1
print(s2)
# Out:
# gitam University cse

# %%
ss="       ggggg        "
print(ss.strip())
print(ss)
print(len(ss.strip()))
# Out:
# ggggg
#        ggggg
# 5

# %%
print(s[0:4])
print(s[-1:0])
# Out:
# gita

# %%
s=(1,2,3,4,5)
print(s[:5:2])
# Out:
# (1, 3, 5)
